# %%
import numpy as np
import matplotlib.pyplot as plt
from GPy.models import BayesianGPLVM
from sklearn.datasets import make_moons, make_swiss_roll, make_circles, make_s_curve


def fit_nd_plot_gplvm(Y):
    model = BayesianGPLVM(Y, 2, init='PCA')
    model.optimize_restarts(15, optimizer='lbfgs')


    E_ygY, V_ygY = model.predict(np.random.normal(size=(500, 2)))
    Y_samp = E_ygY + np.random.normal(0, np.sqrt(V_ygY))
    plt.scatter(Y_samp[:, 0], Y_samp[:, 1], label='sample')
    plt.scatter(Y[:, 0], Y[:, 1], alpha=0.3, label='data')
    plt.legend()

np.random.seed(42); plt.ion(); plt.style.use('ggplot')
n = 500

# %%
Y_moons, c = make_moons(n, noise=0.1)
fit_nd_plot_gplvm(Y_moons)
# Out:
# Optimization restart 1/10, f = 877.5095192121425
# Optimization restart 2/10, f = 707.67846555494
# Optimization restart 3/10, f = 714.0942823353821
# Optimization restart 4/10, f = 1089.6914950447315
# Optimization restart 5/10, f = 1089.691497130288
# Optimization restart 6/10, f = 1220.8557180460145
# Optimization restart 7/10, f = 762.5674566962455
# Optimization restart 8/10, f = 792.4346240352427
# Optimization restart 9/10, f = 1089.6915251292514
# Optimization restart 10/10, f = 891.1491043775577

# %%
from GPy.kern import OU

kern = OU(2)

# %%
Y_spiral, c =  make_swiss_roll(n_samples=n, noise=1.2)
Y_spiral = Y_spiral[:,[0,2]]

fit_nd_plot_gplvm(Y_spiral)
# Out:
# Optimization restart 1/15, f = 3308.9891545890664
# Optimization restart 2/15, f = 3348.2942051829195
# Optimization restart 3/15, f = 3348.2942080678126
# Optimization restart 4/15, f = 3348.294208635968
# Optimization restart 5/15, f = 3348.2942810268705
# Optimization restart 6/15, f = 3348.2942153537338
# Optimization restart 7/15, f = 3348.2942109183687
# Optimization restart 8/15, f = 3348.2942287700603
# Optimization restart 9/15, f = 3348.2942236494805
# Optimization restart 10/15, f = 3348.294212988312
# Optimization restart 11/15, f = 3348.2942004931474
# Optimization restart 12/15, f = 3348.294200720068
# Optimization restart 13/15, f = 3348.294201733656
# Optimization restart 14/15, f = 3265.881654442263
# Optimization restart 15/15, f = 3348.2942239312815

# %%
Y_circles, c = make_circles(n, factor=0.9, noise=0.03)
fit_nd_plot_gplvm(Y_circles)
# Out:
# Optimization restart 1/15, f = 790.5674049440718
# Optimization restart 2/15, f = 1021.5735647114013
# Optimization restart 3/15, f = 1021.5718057336189
# Optimization restart 4/15, f = 1021.5717915386756
# Optimization restart 5/15, f = 1021.5718115794687
# Optimization restart 6/15, f = 1021.5717845271042
# Optimization restart 7/15, f = 1021.5717865916857
# Optimization restart 8/15, f = 1021.5717857842545
# Optimization restart 9/15, f = 1021.5718528073384
# Optimization restart 10/15, f = 1021.5718454619721
# Optimization restart 11/15, f = 1021.5717854059362
# Optimization restart 12/15, f = 1021.571887158409
# Optimization restart 13/15, f = 1021.5717995494224
# Optimization restart 14/15, f = 1021.5717869465134
# Optimization restart 15/15, f = 1021.5717846351808

# %%
def make_checkeboard(npar):
    x1 = np.random.rand(npar) * 4 - 2
    x2_ = np.random.rand(npar) - np.random.randint(0, 2, npar) * 2
    x2 = x2_ + (np.floor(x1) % 2)
    x = np.concatenate([x1[:, None], x2[:, None]], 1) * 7.5
    return x

# %%
Y_board = make_checkeboard(n)
fit_nd_plot_gplvm(Y_board)
# Out:
# Optimization restart 1/15, f = 3541.7065716629154
# Optimization restart 2/15, f = 3617.116927758878
# Optimization restart 3/15, f = 3612.4551991561325
# Optimization restart 4/15, f = 3617.1169166588625
# Optimization restart 5/15, f = 3612.4635701134684
# Optimization restart 6/15, f = 3617.11692511181
# Optimization restart 7/15, f = 3617.116922993637
# Optimization restart 8/15, f = 3617.1169282041237
# Optimization restart 9/15, f = 3612.460498862425
# Optimization restart 10/15, f = 3617.1169217184092
# Optimization restart 11/15, f = 3617.116933369745
# Optimization restart 12/15, f = 3612.457935905626
# Optimization restart 13/15, f = 3617.116920305805
# Optimization restart 14/15, f = 3617.1169149452016
# Optimization restart 15/15, f = 3617.1169360639337

# %%
Y_scurve, c =  make_s_curve(n_samples=n, noise=0.1)
Y_scurve = Y_scurve[:,[0,2]]

fit_nd_plot_gplvm(Y_scurve)
# Out:
# Optimization restart 1/15, f = 1278.2842445684728
# Optimization restart 2/15, f = 1524.097939635458
# Optimization restart 3/15, f = 1524.097827034362
# Optimization restart 4/15, f = 1524.0978234554595
# Optimization restart 5/15, f = 1524.097859952452
# Optimization restart 6/15, f = 1524.09975663362
# Optimization restart 7/15, f = 1524.0979020101008
# Optimization restart 8/15, f = 1524.1015349717907
# Optimization restart 9/15, f = 1524.0978230521048
# Optimization restart 10/15, f = 1524.0978703332007
# Optimization restart 11/15, f = 1524.0984727660561
# Optimization restart 12/15, f = 1524.0978537192223
# Optimization restart 13/15, f = 1524.0979145734586
# Optimization restart 14/15, f = 1524.097884566426
# Optimization restart 15/15, f = 1524.0978235320513
